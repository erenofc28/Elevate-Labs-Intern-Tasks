# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/Housing.csv")

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
x = df.drop(columns=["price","stories","basement","hotwaterheating","airconditioning"])
y = df["price"]

# %%
x.head()
# Out:
#    area  bedrooms  bathrooms mainroad guestroom  parking prefarea  \
# 0  7420         4          2      yes        no        2      yes
# 1  8960         4          4      yes        no        3       no
# 2  9960         3          2      yes        no        2      yes
# 3  7500         4          2      yes        no        3      yes
# 4  7420         4          1      yes       yes        2       no
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
x["mainroad"] = label_encoder.fit_transform(x["mainroad"])
x["prefarea"] = label_encoder.fit_transform(x["prefarea"])
x["furnishingstatus"] = label_encoder.fit_transform(x["furnishingstatus"])
x["guestroom"] = label_encoder.fit_transform(x["guestroom"])

# %%
x.head()
# Out:
#    area  bedrooms  bathrooms  mainroad  guestroom  parking  prefarea  \
# 0  7420         4          2         1          0        2         1
# 1  8960         4          4         1          0        3         0
# 2  9960         3          2         1          0        2         1
# 3  7500         4          2         1          0        3         1
# 4  7420         4          1         1          1        2         0
#
#    furnishingstatus
# 0                 0
# 1                 0
# 2                 1
# 3                 0
# 4                 0

# %%
x.isnull().sum()
# Out:
# area                0
# bedrooms            0
# bathrooms           0
# mainroad            0
# guestroom           0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Predictions
train_preds = model.predict(x_train)
test_preds = model.predict(x_test)

# Metrics
train_mse = mean_squared_error(y_train, train_preds)
test_mse = mean_squared_error(y_test, test_preds)

train_r2 = r2_score(y_train, train_preds)
test_r2 = r2_score(y_test, test_preds)

print("Train MSE:", train_mse)
print("Test MSE:", test_mse)
print("Train R2:", train_r2)
print("Test R2:", test_r2)
# Out:
# Train MSE: 1240389383909.2502
# Test MSE: 2295230938022.8394
# Train R2: 0.5977192546508081
# Test R2: 0.5459097754797554
